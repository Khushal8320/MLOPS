# %%
## mlflow tracking server
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("first_experiment")

with mlflow.start_run():
    mlflow.log_metric("khushal",1)
    mlflow.log_metric("patel",1)
# Out:
# 2026/03/23 16:58:46 INFO mlflow.tracking.fluent: Experiment with name 'first_experiment' does not exist. Creating a new experiment.
# 🏃 View run able-wolf-279 at: http://127.0.0.1:5000/#/experiments/1/runs/f6ae937b61ee423e8f0f49b4148870f5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
mlflow.set_experiment("first_experiment")

with mlflow.start_run():
    mlflow.log_metric("khushal1",1)
    mlflow.log_metric("patel1",1)
# Out:
# 🏃 View run worried-seal-680 at: http://127.0.0.1:5000/#/experiments/1/runs/20755de20e8b4754b5b9a678060e23a0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
